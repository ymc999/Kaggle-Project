# %% [markdown]
# <a href="https://colab.research.google.com/github/ymc999/Kaggle-Project/blob/main/My1st_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(0,500)
plt.plot(x)
plt.title('A simple graph')
plt.show()
